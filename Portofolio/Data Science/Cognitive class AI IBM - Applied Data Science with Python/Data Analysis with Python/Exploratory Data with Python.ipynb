# %% [markdown]
# # Eksploratory Data Analysis

# %% [markdown]
# Setelah melakukan cleaning data, proses selanjutnya melakukan eksplorasi data

# %%
# Memanggil data yang sudah dicleaning

import pandas as pd

import csv
df = pd.read_csv('clean_df.csv', index_col=0)

# %%
df.head()
# Out:
#    symbolling  normalized-losses         make num-of-doors   body-style  \
# 0           3                122  alfa-romero          two  convertible
# 1           3                122  alfa-romero          two  convertible
# 2           1                122  alfa-romero          two    hatchback
# 3           2                164         audi         four        sedan
# 4           2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  \
# 0          rwd           front        88.6  0.811148  0.890278  ...
# 1          rwd           front        88.6  0.811148  0.890278  ...
# 2          rwd           front        94.5  0.822681  0.909722  ...
# 3          fwd           front        99.8  0.848630  0.919444  ...
# 4          4wd           front        99.4  0.848630  0.922222  ...
#
#    horsepower  peak-rpm city-L/100km highway-L/100km  price horsepower-binned  \
# ...

# %%
# melihat korelasi seluruh variabel 

df.corr()
# Out:
#                    symbolling  normalized-losses  wheel-base    length  \
# symbolling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses    0.466264           1.000000   -0.056661  0.019424
# wheel-base          -0.535987          -0.056661    1.000000  0.876024
# length              -0.365404           0.019424    0.876024  1.000000
# width               -0.242423           0.086802    0.814507  0.857170
# height              -0.550160          -0.373737    0.590742  0.492063
# curb-weight         -0.233118           0.099404    0.782097  0.880665
# engine-size         -0.110581           0.112360    0.572027  0.685025
# bore                -0.140019          -0.029862    0.493244  0.608971
# stroke              -0.008153           0.055045    0.158018  0.123952
# compression-ratio   -0.182196          -0.114713    0.250313  0.159733
# horsepower           0.075810           0.217300    0.371178  0.579795
# ...

# %%
# melihat korelasi antar variabel bore, stroke, compressiion-ratio dan horse power

df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566903
# stroke            -0.055390  1.000000           0.187871    0.098128
# compression-ratio  0.001263  0.187871           1.000000   -0.214489
# horsepower         0.566903  0.098128          -0.214489    1.000000

# %%
# Import library matplotlib

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# menampilkan grafik korelasi antar variabel x=engine-size dan y=price

sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0, 56289.576717195414)

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
# Menampilkan grafik korelasi antar variabel x=highway-L/100km dan y=price

sns.regplot(x="highway-L/100km", y="price", data=df)

# %%
df[["highway-L/100km", "price"]].corr()
# Out:
#                  highway-L/100km     price
# highway-L/100km         1.000000 -0.704692
# price                  -0.704692  1.000000

# %%
df[["peak-rpm", "price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
# Menampilkan korelasi antar variabel x=peak-rpm dan y=price

sns.regplot(x="peak-rpm", y="price", data=df)

# %%
# Melihat persebaran data antar variabel x=body-style dan y=price

sns.boxplot(x="body-style", y="price", data=df)

# %%
# Melihat persebaran data antar variabel x=engine-location dan y=price

sns.boxplot(x="engine-location", y="price", data=df)

# %%
# Melihat persebaran data antar variabel x=drive-wheels dan y=price

sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
# Melihat tipe data yang termasuk objek (string)

df.describe(include=["object"])
# Out:
#           make num-of-doors body-style drive-wheels engine-location  \
# count      201          201        201          201             201
# unique      22            2          5            3               2
# top     toyota         four      sedan          fwd           front
# freq        32          115         94          118             198
#
#        engine-type num-of-cylinders fuel-system horsepower-binned
# count          201              201         201               201
# unique           6                7           8                 3
# top            ohc             four        mpfi               Low
# freq           145              157          92               153

# %%
# Menghitung jumlah data pada variabel drive-wheels

df["drive-wheels"].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts = df["drive-wheels"].value_counts().to_frame()
drive_wheels_counts.rename(columns={"drive-wheels": "value_counts"}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts.index.name="drive-wheels"
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
# menghitung data pada variabel engine-location

engine_location_counts = df["engine-location"].value_counts().to_frame()
engine_location_counts.rename(columns={"engine-location": "value_counts"}, inplace=True)
engine_location_counts.index.name = "engine-location"
engine_location_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
df["drive-wheels"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
# Melakukan grouping pada variabel drive-wheels, bdy style dan price

df_group_1 = df[["drive-wheels", "body-style", "price"]]
df_group_1 = df_group_1.groupby(["drive-wheels"], as_index=False).mean()
df_group_1
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
df_gptest = df[["drive-wheels", "body-style", "price"]]
group_test1 = df_gptest.groupby(["drive-wheels", "body-style"], as_index=False).mean()
group_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
# Menggunakan pivot tabel pada variabel drive-wheels dan body-style

group_pivot = group_test1.pivot(index="drive-wheels", columns="body-style")
group_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
group_pivot = group_pivot.fillna(0)
group_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
# Melihat korelasi antar variabel drive-wheels body style dan price dengan menggunakan heatmap

plt.pcolor(group_pivot, cmap="RdBu")
plt.colorbar()
plt.show()

# %%
# Memberikan keterangan dan label pada heatmap

import numpy as np

fig, ax = plt.subplots()
im = ax.pcolor(group_pivot, cmap = "RdBu")

#Label names
row_labels = group_pivot.columns.levels[1]
col_labels = group_pivot.index

# Memindahkan label dan ticks ke tengah
ax.set_xticks(np.arange(group_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(group_pivot.shape[0]) + 0.5, minor=False)

#Insert Label
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
# Menghitung Pearson korelasi dan p value beberapa variabel

from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df["wheel-base"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.584641822265508 dengan nilai p-value = 8.076488270733218e-20

# %%
pearson_coef, p_value = stats.pearsonr(df["horsepower"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.8096068016571054 dengan nilai p-value = 6.273536270650504e-48

# %%
pearson_coef, p_value = stats.pearsonr(df["length"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.690628380448364 dengan nilai p-value = 8.016477466158986e-30

# %%
pearson_coef, p_value = stats.pearsonr(df["width"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.7512653440522684 dengan nilai p-value = 9.200335510478379e-38

# %%
pearson_coef, p_value = stats.pearsonr(df["curb-weight"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.8344145257702844 dengan nilai p-value = 2.189577238893878e-53

# %%
pearson_coef, p_value = stats.pearsonr(df["engine-size"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.8723351674455185 dengan nilai p-value = 9.265491622198389e-64

# %%
pearson_coef, p_value = stats.pearsonr(df["bore"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.5431553832626603 dengan nilai p-value = 8.049189483935261e-17

# %%
pearson_coef, p_value = stats.pearsonr(df["city-L/100km"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah 0.7898975136626945 dengan nilai p-value = 3.9031064009395806e-44

# %%
pearson_coef, p_value = stats.pearsonr(df["highway-L/100km"], df["price"])
print("Nilai koefisien person correlation adalah", pearson_coef, "dengan nilai p-value =", p_value)
# Out:
# Nilai koefisien person correlation adalah -0.7046922650589529 dengan nilai p-value = 1.7495471144477352e-31

# %%
# Melakukan gruping variabel drive-wheels dan price

group_test2 = df_gptest[["drive-wheels", "price"]].groupby(["drive-wheels"])
group_test2.head()
# Out:
#     drive-wheels  price
# 0            rwd  13495
# 1            rwd  16500
# 2            rwd  16500
# 3            fwd  13950
# 4            4wd  17450
# 5            fwd  15250
# 6            fwd  17710
# 7            fwd  18920
# 8            fwd  23875
# 9            rwd  16430
# 10           rwd  16925
# 136          4wd   7603
# 140          4wd   9233
# 141          4wd  11259
# 144          4wd   8013

# %%
df_gptest
# Out:
#     drive-wheels   body-style  price
# 0            rwd  convertible  13495
# 1            rwd  convertible  16500
# 2            rwd    hatchback  16500
# 3            fwd        sedan  13950
# 4            4wd        sedan  17450
# ..           ...          ...    ...
# 196          rwd        sedan  16845
# 197          rwd        sedan  19045
# 198          rwd        sedan  21485
# 199          rwd        sedan  22470
# 200          rwd        sedan  22625
#
# [201 rows x 3 columns]

# %%
group_test2.get_group("4wd")["price"]
# Out:
# 4      17450
# 136     7603
# 140     9233
# 141    11259
# 144     8013
# 145    11694
# 150     7898
# 151     8778
# Name: price, dtype: int64

# %%
# Melakukan uji ANOVA pada variabel

f_val, p_val = stats.f_oneway(group_test2.get_group('fwd')['price'], group_test2.get_group('rwd')['price'], group_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
f_val, p_val = stats.f_oneway(group_test2.get_group('fwd')['price'], group_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
f_val, p_val = stats.f_oneway(group_test2.get_group('4wd')['price'], group_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
f_val, p_val = stats.f_oneway(group_test2.get_group('4wd')['price'], group_test2.get_group('fwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666
